# %% [markdown]
# # Notebook 4 — Conclusions
#
# ## 4.1 Key Findings
# - Summarize DQ issues identified
# - Summarize cleaning impact and ML behavior
#
# ## 4.2 Limitations
# - Discuss cultural data ambiguity, subjective labels, long-tail classes, and lack of ground truth
#
# ## 4.3 Final Remarks
# - Tie back to DIQ philosophy: data quality is context-dependent and improvement is bounded by semantics
#
# Presentation note: craft short, slide-ready bullet points and a single concluding paragraph linking back to project goals.
