# %% [markdown]
# # Notebook 3 — ML Pipeline (Classification)
#
# ## 3.1 Feature Definition
# - Define text features and numeric features to use
# - Justify feature choice based on availability and semantic relevance
#
# ## 3.2 Baseline Model (Dirty Data)
# - Train a simple baseline (Logistic Regression or Random Forest) on uncleaned data
# - Metrics: Accuracy and Macro F1
#
# ## 3.3 Model on Cleaned Data
# - Repeat with the cleaned dataset using same split and model configuration
# - Report the same metrics for direct comparison
#
# ## 3.4 Results Comparison
# - Table: Dirty vs Clean performance
# - Per-class performance and discussion
#
# Guidance: keep modeling pipeline simple and reproducible; focus on demonstrating the impact of cleaning.
