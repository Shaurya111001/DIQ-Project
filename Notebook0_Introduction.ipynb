# %% [markdown]
# # Notebook 0 — Introduction & Goal
#
# ## 0.1 — Project Goal
# - Dataset: Met Museum (met_museum_objects.csv)
# - Project type: 3-people → Data Science pipeline
# - ML task: Classification
# - Target variable: Department
#
# ### Key justification
# - Department has a limited number of classes
# - 0% missing for the target
# - Semantically meaningful labels for ML
#
# Write-up prompt:
# - Explain why Department is chosen as the target and how this aligns with project constraints and slide guidance. Keep this section short and slide-ready.
